# %%
import numpy as np
import matplotlib.pyplot as plt
from impls import *

# %%
# X_train, y_train, X_test, y_test, X_trial, y_trial = load_proj_data()
X_train, y_train, X_test, y_test, X_trial, y_trial = load_proj_data()


plt.imshow(X_train[0].reshape(32,32))
plt.show()
